# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %%
root_dir = '../sdc.broadband_dev'
print(os.path.isdir(root_dir))
# Out:
# True

# %%
paths = [path for path in Path(root_dir).rglob("distribution/**/*.csv.xz")]
print(len(paths))
# Out:
# 37

# %%
def binarize_null(df):
    df = df.copy()
    for col in df.columns:
        df[col] = df[col].apply(lambda x: 1 if pd.isnull(x) else 0)
    return df

# %%
for path in paths:
    df = pd.read_csv(path, low_memory=False)
    bdf = binarize_null(df)        
    if bdf.sum()['year'] > 0:
        print(path)
        print(bdf.sum())
        print(df[df['year'].isnull()])
        print('-'*80)
# Out:
# ../sdc.broadband_dev/legacy/data/dc.ookla.broadband/distribution/ncr_cttrbg_2019_2021_percent_above_threshold_mobile.csv.xz
# geoid                 0
# region_type           0
# region_name           0
# year                 24
# measure               0
# value               492
# measure_type          0
# measure_units    322152
# dtype: int64
#                geoid  region_type  \
# 99864   240178513021  block group
# 104084  240178513021  block group
# 108306  240178513021  block group
# 112528  240178513021  block group
# 116748  240178513021  block group
# 125192  240178513021  block group
# 129413  240178513021  block group
# 133633  240178513021  block group
# 137852  240178513021  block group
# 142063  240178513021  block group
# 146284  240178513021  block group
# 150491  240178513021  block group
# 154711  240178513021  block group
# 158930  240178513021  block group
# 163149  240178513021  block group
# 167368  240178513021  block group
# 171587  240178513021  block group
# 175806  240178513021  block group
# 180025  240178513021  block group
# 184243  240178513021  block group
# 188463  240178513021  block group
# 192685  240178513021  block group
# 196905  240178513021  block group
# 201119  240178513021  block group
#
#                                               region_name  year  \
# 99864   Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 104084  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 108306  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 112528  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 116748  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 125192  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 129413  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 133633  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 137852  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 142063  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 146284  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 150491  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 154711  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 158930  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 163149  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 167368  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 171587  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 175806  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 180025  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 184243  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 188463  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 192685  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 196905  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 201119  Block Group 1, Census Tract 8513.02, Charles C...   NaN
#
#                                         measure  value measure_type  \
# 99864     perc_w_int_above_100_down_using_tests    NaN      percent
# 104084  perc_w_int_above_100_down_using_devices    NaN      percent
# 108306   perc_w_int_above_25_down_using_devices    NaN      percent
# 112528     perc_w_int_above_20_up_using_devices    NaN      percent
# 116748      perc_w_int_above_3_up_using_devices    NaN      percent
# 125192     perc_w_int_above_25_down_using_tests    NaN      percent
# 129413       perc_w_int_above_20_up_using_tests    NaN      percent
# 133633        perc_w_int_above_3_up_using_tests    NaN      percent
# 137852          perc_w_int_100_20_using_devices    NaN      percent
# 142063            perc_w_int_25_3_using_devices    NaN      percent
# 146284            perc_w_int_100_20_using_tests    NaN      percent
# 150491              perc_w_int_25_3_using_tests    NaN      percent
# 154711  perc_total_above_100_down_using_devices    NaN      percent
# 158930   perc_total_above_25_down_using_devices    NaN      percent
# 163149     perc_total_above_20_up_using_devices    NaN      percent
# 167368      perc_total_above_3_up_using_devices    NaN      percent
# 171587    perc_total_above_100_down_using_tests    NaN      percent
# 175806     perc_total_above_25_down_using_tests    NaN      percent
# 180025       perc_total_above_20_up_using_tests    NaN      percent
# 184243        perc_total_above_3_up_using_tests    NaN      percent
# 188463          perc_total_100_20_using_devices    NaN      percent
# 192685            perc_total_25_3_using_devices    NaN      percent
# 196905            perc_total_100_20_using_tests    NaN      percent
# 201119              perc_total_25_3_using_tests    NaN      percent
#
#         measure_units
# 99864             NaN
# 104084            NaN
# 108306            NaN
# 112528            NaN
# 116748            NaN
# 125192            NaN
# 129413            NaN
# 133633            NaN
# 137852            NaN
# 142063            NaN
# 146284            NaN
# 150491            NaN
# 154711            NaN
# 158930            NaN
# 163149            NaN
# 167368            NaN
# 171587            NaN
# 175806            NaN
# 180025            NaN
# 184243            NaN
# 188463            NaN
# 192685            NaN
# 196905            NaN
# 201119            NaN
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.ookla.broadband/distribution/dcmdva_hdcttrbg_2019_2021q3_percent_above_threshold.csv.xz
# geoid                 0
# region_type           0
# region_name           0
# year                624
# measure               0
# value              2712
# measure_type          0
# measure_units    958632
# dtype: int64
#                geoid  region_type  \
# 85      510019902000  block group
# 93      510019901000  block group
# 2419    510019901000  block group
# 2569    510539801001  block group
# 6350    511039901000  block group
# ...              ...          ...
# 811891  240359901000  block group
# 811892  240379900000  block group
# 811893  240399901000  block group
# 811894  240419900000  block group
# 811895  240479900000  block group
#
#                                               region_name  year  \
# 85      Block Group 0, Census Tract 9902, Accomack Cou...   NaN
# 93      Block Group 0, Census Tract 9901, Accomack Cou...   NaN
# 2419    Block Group 0, Census Tract 9901, Accomack Cou...   NaN
# 2569    Block Group 1, Census Tract 9801, Dinwiddie Co...   NaN
# 6350    Block Group 0, Census Tract 9901, Lancaster Co...   NaN
# ...                                                   ...   ...
# 811891  Block Group 0, Census Tract 9901, Queen Anne's...   NaN
# 811892  Block Group 0, Census Tract 9900, St. Mary's C...   NaN
# 811893  Block Group 0, Census Tract 9901, Somerset Cou...   NaN
# 811894  Block Group 0, Census Tract 9900, Talbot Count...   NaN
# 811895  Block Group 0, Census Tract 9900, Worcester Co...   NaN
#
#                                         measure  value measure_type  \
# 85      perc_w_int_above_100_down_using_devices    NaN      percent
# 93      perc_w_int_above_100_down_using_devices    NaN      percent
# 2419        perc_w_int_above_3_up_using_devices    NaN      percent
# 2569    perc_w_int_above_100_down_using_devices    NaN      percent
# 6350    perc_w_int_above_100_down_using_devices    NaN      percent
# ...                                         ...    ...          ...
# 811891              perc_total_25_3_using_tests    NaN      percent
# 811892              perc_total_25_3_using_tests    NaN      percent
# 811893              perc_total_25_3_using_tests    NaN      percent
# 811894              perc_total_25_3_using_tests    NaN      percent
# 811895              perc_total_25_3_using_tests    NaN      percent
#
#         measure_units
# 85                NaN
# 93                NaN
# 2419              NaN
# 2569              NaN
# 6350              NaN
# ...               ...
# 811891            NaN
# 811892            NaN
# 811893            NaN
# 811894            NaN
# 811895            NaN
#
# [624 rows x 8 columns]
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.ookla.broadband/distribution/ncr_cttrbg_2019_2021_percent_above_threshold_fixed.csv.xz
# geoid                 0
# region_type           0
# region_name           0
# year                 24
# measure               0
# value               492
# measure_type          0
# measure_units    322224
# dtype: int64
#                geoid  region_type  \
# 104085  240178513021  block group
# 108308  240178513021  block group
# 112533  240178513021  block group
# 116755  240178513021  block group
# 120980  240178513021  block group
# 125203  240178513021  block group
# 129426  240178513021  block group
# 133648  240178513021  block group
# 137870  240178513021  block group
# 142089  240178513021  block group
# 146307  240178513021  block group
# 150527  240178513021  block group
# 154750  240178513021  block group
# 154829  240178513021  block group
# 158973  240178513021  block group
# 163195  240178513021  block group
# 167416  240178513021  block group
# 171639  240178513021  block group
# 175861  240178513021  block group
# 180082  240178513021  block group
# 188525  240178513021  block group
# 192749  240178513021  block group
# 196971  240178513021  block group
# 201191  240178513021  block group
#
#                                               region_name  year  \
# 104085  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 108308  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 112533  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 116755  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 120980  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 125203  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 129426  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 133648  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 137870  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 142089  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 146307  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 150527  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 154750  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 154829  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 158973  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 163195  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 167416  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 171639  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 175861  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 180082  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 188525  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 192749  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 196971  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 201191  Block Group 1, Census Tract 8513.02, Charles C...   NaN
#
#                                         measure  value measure_type  \
# 104085  perc_w_int_above_100_down_using_devices    NaN      percent
# 108308   perc_w_int_above_25_down_using_devices    NaN      percent
# 112533     perc_w_int_above_20_up_using_devices    NaN      percent
# 116755      perc_w_int_above_3_up_using_devices    NaN      percent
# 120980    perc_w_int_above_100_down_using_tests    NaN      percent
# 125203     perc_w_int_above_25_down_using_tests    NaN      percent
# 129426       perc_w_int_above_20_up_using_tests    NaN      percent
# 133648        perc_w_int_above_3_up_using_tests    NaN      percent
# 137870          perc_w_int_100_20_using_devices    NaN      percent
# 142089            perc_w_int_25_3_using_devices    NaN      percent
# 146307            perc_w_int_100_20_using_tests    NaN      percent
# 150527              perc_w_int_25_3_using_tests    NaN      percent
# 154750  perc_total_above_100_down_using_devices    NaN      percent
# 154829        perc_total_above_3_up_using_tests    NaN      percent
# 158973   perc_total_above_25_down_using_devices    NaN      percent
# 163195     perc_total_above_20_up_using_devices    NaN      percent
# 167416      perc_total_above_3_up_using_devices    NaN      percent
# 171639    perc_total_above_100_down_using_tests    NaN      percent
# 175861     perc_total_above_25_down_using_tests    NaN      percent
# 180082       perc_total_above_20_up_using_tests    NaN      percent
# 188525          perc_total_100_20_using_devices    NaN      percent
# 192749            perc_total_25_3_using_devices    NaN      percent
# 196971            perc_total_100_20_using_tests    NaN      percent
# 201191              perc_total_25_3_using_tests    NaN      percent
#
#         measure_units
# 104085            NaN
# 108308            NaN
# 112533            NaN
# 116755            NaN
# 120980            NaN
# 125203            NaN
# 129426            NaN
# 133648            NaN
# 137870            NaN
# 142089            NaN
# 146307            NaN
# 150527            NaN
# 154750            NaN
# 154829            NaN
# 158973            NaN
# 163195            NaN
# 167416            NaN
# 171639            NaN
# 175861            NaN
# 180082            NaN
# 188525            NaN
# 192749            NaN
# 196971            NaN
# 201191            NaN
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/Wired/Accessibility/Percent Fast (internet-connected)/data/distribution/ncr_hdcttrbg_2019_2021q3_percent_above_threshold.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                26
# measure              0
# value               26
# measure_type         0
# measure_units    39943
# dtype: int64
#               geoid  region_type  \
# 90     510019902000  block group
# 98     510019901000  block group
# 2568   510539801001  block group
# 6350   511039901000  block group
# 7063   511159901000  block group
# 7181   511199901000  block group
# 7444   511319901000  block group
# 7462   511339901000  block group
# 9916   511838702021  block group
# 10349  511959307003  block group
# 10363  511959312003  block group
# 10485  511999901000  block group
# 12053  516509901000  block group
# 13544  517359901000  block group
# 14860  518000751010  block group
# 33818  240039900000  block group
# 33819  240099901000  block group
# 33820  240178513021  block group
# 33821  240199900000  block group
# 33822  240299900000  block group
# 33823  240359900000  block group
# 33824  240359901000  block group
# 33825  240379900000  block group
# 33826  240399901000  block group
# 33827  240419900000  block group
# 33828  240479900000  block group
#
#                                              region_name  year  \
# 90     Block Group 0, Census Tract 9902, Accomack Cou...   NaN
# 98     Block Group 0, Census Tract 9901, Accomack Cou...   NaN
# 2568   Block Group 1, Census Tract 9801, Dinwiddie Co...   NaN
# 6350   Block Group 0, Census Tract 9901, Lancaster Co...   NaN
# 7063   Block Group 0, Census Tract 9901, Mathews Coun...   NaN
# 7181   Block Group 0, Census Tract 9901, Middlesex Co...   NaN
# 7444   Block Group 0, Census Tract 9901, Northampton ...   NaN
# 7462   Block Group 0, Census Tract 9901, Northumberla...   NaN
# 9916   Block Group 1, Census Tract 8702.02, Sussex Co...   NaN
# 10349  Block Group 3, Census Tract 9307, Wise County,...   NaN
# 10363  Block Group 3, Census Tract 9312, Wise County,...   NaN
# 10485  Block Group 0, Census Tract 9901, York County,...   NaN
# 12053  Block Group 0, Census Tract 9901, Hampton city...   NaN
# 13544  Block Group 0, Census Tract 9901, Poquoson cit...   NaN
# 14860  Block Group 0, Census Tract 751.01, Suffolk ci...   NaN
# 33818  Block Group 0, Census Tract 9900, Anne Arundel...   NaN
# 33819  Block Group 0, Census Tract 9901, Calvert Coun...   NaN
# 33820  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 33821  Block Group 0, Census Tract 9900, Dorchester C...   NaN
# 33822  Block Group 0, Census Tract 9900, Kent County,...   NaN
# 33823  Block Group 0, Census Tract 9900, Queen Anne's...   NaN
# 33824  Block Group 0, Census Tract 9901, Queen Anne's...   NaN
# 33825  Block Group 0, Census Tract 9900, St. Mary's C...   NaN
# 33826  Block Group 0, Census Tract 9901, Somerset Cou...   NaN
# 33827  Block Group 0, Census Tract 9900, Talbot Count...   NaN
# 33828  Block Group 0, Census Tract 9900, Worcester Co...   NaN
#
#                                measure  value measure_type  measure_units
# 90     perc_w_int_100_20_using_devices    NaN      percent            NaN
# 98     perc_w_int_100_20_using_devices    NaN      percent            NaN
# 2568   perc_w_int_100_20_using_devices    NaN      percent            NaN
# 6350   perc_w_int_100_20_using_devices    NaN      percent            NaN
# 7063   perc_w_int_100_20_using_devices    NaN      percent            NaN
# 7181   perc_w_int_100_20_using_devices    NaN      percent            NaN
# 7444   perc_w_int_100_20_using_devices    NaN      percent            NaN
# 7462   perc_w_int_100_20_using_devices    NaN      percent            NaN
# 9916   perc_w_int_100_20_using_devices    NaN      percent            NaN
# 10349  perc_w_int_100_20_using_devices    NaN      percent            NaN
# 10363  perc_w_int_100_20_using_devices    NaN      percent            NaN
# 10485  perc_w_int_100_20_using_devices    NaN      percent            NaN
# 12053  perc_w_int_100_20_using_devices    NaN      percent            NaN
# 13544  perc_w_int_100_20_using_devices    NaN      percent            NaN
# 14860  perc_w_int_100_20_using_devices    NaN      percent            NaN
# 33818  perc_w_int_100_20_using_devices    NaN      percent            NaN
# 33819  perc_w_int_100_20_using_devices    NaN      percent            NaN
# 33820  perc_w_int_100_20_using_devices    NaN      percent            NaN
# 33821  perc_w_int_100_20_using_devices    NaN      percent            NaN
# 33822  perc_w_int_100_20_using_devices    NaN      percent            NaN
# 33823  perc_w_int_100_20_using_devices    NaN      percent            NaN
# 33824  perc_w_int_100_20_using_devices    NaN      percent            NaN
# 33825  perc_w_int_100_20_using_devices    NaN      percent            NaN
# 33826  perc_w_int_100_20_using_devices    NaN      percent            NaN
# 33827  perc_w_int_100_20_using_devices    NaN      percent            NaN
# 33828  perc_w_int_100_20_using_devices    NaN      percent            NaN
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/Wired/Accessibility/Percent Good (internet-connected)/data/distribution/ncr_hdcttrbg_2019_2021q3_percent_above_threshold.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                26
# measure              0
# value               26
# measure_type         0
# measure_units    39943
# dtype: int64
#               geoid  region_type  \
# 85     510019902000  block group
# 93     510019901000  block group
# 2568   510539801001  block group
# 6349   511039901000  block group
# 7063   511159901000  block group
# 7181   511199901000  block group
# 7444   511319901000  block group
# 7462   511339901000  block group
# 9916   511838702021  block group
# 10349  511959307003  block group
# 10363  511959312003  block group
# 10485  511999901000  block group
# 12052  516509901000  block group
# 13544  517359901000  block group
# 14860  518000751010  block group
# 33818  240039900000  block group
# 33819  240099901000  block group
# 33820  240178513021  block group
# 33821  240199900000  block group
# 33822  240299900000  block group
# 33823  240359900000  block group
# 33824  240359901000  block group
# 33825  240379900000  block group
# 33826  240399901000  block group
# 33827  240419900000  block group
# 33828  240479900000  block group
#
#                                              region_name  year  \
# 85     Block Group 0, Census Tract 9902, Accomack Cou...   NaN
# 93     Block Group 0, Census Tract 9901, Accomack Cou...   NaN
# 2568   Block Group 1, Census Tract 9801, Dinwiddie Co...   NaN
# 6349   Block Group 0, Census Tract 9901, Lancaster Co...   NaN
# 7063   Block Group 0, Census Tract 9901, Mathews Coun...   NaN
# 7181   Block Group 0, Census Tract 9901, Middlesex Co...   NaN
# 7444   Block Group 0, Census Tract 9901, Northampton ...   NaN
# 7462   Block Group 0, Census Tract 9901, Northumberla...   NaN
# 9916   Block Group 1, Census Tract 8702.02, Sussex Co...   NaN
# 10349  Block Group 3, Census Tract 9307, Wise County,...   NaN
# 10363  Block Group 3, Census Tract 9312, Wise County,...   NaN
# 10485  Block Group 0, Census Tract 9901, York County,...   NaN
# 12052  Block Group 0, Census Tract 9901, Hampton city...   NaN
# 13544  Block Group 0, Census Tract 9901, Poquoson cit...   NaN
# 14860  Block Group 0, Census Tract 751.01, Suffolk ci...   NaN
# 33818  Block Group 0, Census Tract 9900, Anne Arundel...   NaN
# 33819  Block Group 0, Census Tract 9901, Calvert Coun...   NaN
# 33820  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 33821  Block Group 0, Census Tract 9900, Dorchester C...   NaN
# 33822  Block Group 0, Census Tract 9900, Kent County,...   NaN
# 33823  Block Group 0, Census Tract 9900, Queen Anne's...   NaN
# 33824  Block Group 0, Census Tract 9901, Queen Anne's...   NaN
# 33825  Block Group 0, Census Tract 9900, St. Mary's C...   NaN
# 33826  Block Group 0, Census Tract 9901, Somerset Cou...   NaN
# 33827  Block Group 0, Census Tract 9900, Talbot Count...   NaN
# 33828  Block Group 0, Census Tract 9900, Worcester Co...   NaN
#
#                              measure  value measure_type  measure_units
# 85     perc_w_int_25_3_using_devices    NaN      percent            NaN
# 93     perc_w_int_25_3_using_devices    NaN      percent            NaN
# 2568   perc_w_int_25_3_using_devices    NaN      percent            NaN
# 6349   perc_w_int_25_3_using_devices    NaN      percent            NaN
# 7063   perc_w_int_25_3_using_devices    NaN      percent            NaN
# 7181   perc_w_int_25_3_using_devices    NaN      percent            NaN
# 7444   perc_w_int_25_3_using_devices    NaN      percent            NaN
# 7462   perc_w_int_25_3_using_devices    NaN      percent            NaN
# 9916   perc_w_int_25_3_using_devices    NaN      percent            NaN
# 10349  perc_w_int_25_3_using_devices    NaN      percent            NaN
# 10363  perc_w_int_25_3_using_devices    NaN      percent            NaN
# 10485  perc_w_int_25_3_using_devices    NaN      percent            NaN
# 12052  perc_w_int_25_3_using_devices    NaN      percent            NaN
# 13544  perc_w_int_25_3_using_devices    NaN      percent            NaN
# 14860  perc_w_int_25_3_using_devices    NaN      percent            NaN
# 33818  perc_w_int_25_3_using_devices    NaN      percent            NaN
# 33819  perc_w_int_25_3_using_devices    NaN      percent            NaN
# 33820  perc_w_int_25_3_using_devices    NaN      percent            NaN
# 33821  perc_w_int_25_3_using_devices    NaN      percent            NaN
# 33822  perc_w_int_25_3_using_devices    NaN      percent            NaN
# 33823  perc_w_int_25_3_using_devices    NaN      percent            NaN
# 33824  perc_w_int_25_3_using_devices    NaN      percent            NaN
# 33825  perc_w_int_25_3_using_devices    NaN      percent            NaN
# 33826  perc_w_int_25_3_using_devices    NaN      percent            NaN
# 33827  perc_w_int_25_3_using_devices    NaN      percent            NaN
# 33828  perc_w_int_25_3_using_devices    NaN      percent            NaN
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/Wired/Accessibility/Percent Fast (total)/data/distribution/ncr_hdcttrbg_2019_2021q3_percent_above_threshold.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                26
# measure              0
# value              200
# measure_type         0
# measure_units    39943
# dtype: int64
#               geoid  region_type  \
# 85     510019902000  block group
# 93     510019901000  block group
# 2568   510539801001  block group
# 6349   511039901000  block group
# 7063   511159901000  block group
# 7181   511199901000  block group
# 7444   511319901000  block group
# 7462   511339901000  block group
# 9916   511838702021  block group
# 10349  511959307003  block group
# 10363  511959312003  block group
# 10485  511999901000  block group
# 12052  516509901000  block group
# 13544  517359901000  block group
# 14860  518000751010  block group
# 33818  240039900000  block group
# 33819  240099901000  block group
# 33820  240178513021  block group
# 33821  240199900000  block group
# 33822  240299900000  block group
# 33823  240359900000  block group
# 33824  240359901000  block group
# 33825  240379900000  block group
# 33826  240399901000  block group
# 33827  240419900000  block group
# 33828  240479900000  block group
#
#                                              region_name  year  \
# 85     Block Group 0, Census Tract 9902, Accomack Cou...   NaN
# 93     Block Group 0, Census Tract 9901, Accomack Cou...   NaN
# 2568   Block Group 1, Census Tract 9801, Dinwiddie Co...   NaN
# 6349   Block Group 0, Census Tract 9901, Lancaster Co...   NaN
# 7063   Block Group 0, Census Tract 9901, Mathews Coun...   NaN
# 7181   Block Group 0, Census Tract 9901, Middlesex Co...   NaN
# 7444   Block Group 0, Census Tract 9901, Northampton ...   NaN
# 7462   Block Group 0, Census Tract 9901, Northumberla...   NaN
# 9916   Block Group 1, Census Tract 8702.02, Sussex Co...   NaN
# 10349  Block Group 3, Census Tract 9307, Wise County,...   NaN
# 10363  Block Group 3, Census Tract 9312, Wise County,...   NaN
# 10485  Block Group 0, Census Tract 9901, York County,...   NaN
# 12052  Block Group 0, Census Tract 9901, Hampton city...   NaN
# 13544  Block Group 0, Census Tract 9901, Poquoson cit...   NaN
# 14860  Block Group 0, Census Tract 751.01, Suffolk ci...   NaN
# 33818  Block Group 0, Census Tract 9900, Anne Arundel...   NaN
# 33819  Block Group 0, Census Tract 9901, Calvert Coun...   NaN
# 33820  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 33821  Block Group 0, Census Tract 9900, Dorchester C...   NaN
# 33822  Block Group 0, Census Tract 9900, Kent County,...   NaN
# 33823  Block Group 0, Census Tract 9900, Queen Anne's...   NaN
# 33824  Block Group 0, Census Tract 9901, Queen Anne's...   NaN
# 33825  Block Group 0, Census Tract 9900, St. Mary's C...   NaN
# 33826  Block Group 0, Census Tract 9901, Somerset Cou...   NaN
# 33827  Block Group 0, Census Tract 9900, Talbot Count...   NaN
# 33828  Block Group 0, Census Tract 9900, Worcester Co...   NaN
#
#                                measure  value measure_type  measure_units
# 85     perc_total_100_20_using_devices    NaN      percent            NaN
# 93     perc_total_100_20_using_devices    NaN      percent            NaN
# 2568   perc_total_100_20_using_devices    NaN      percent            NaN
# 6349   perc_total_100_20_using_devices    NaN      percent            NaN
# 7063   perc_total_100_20_using_devices    NaN      percent            NaN
# 7181   perc_total_100_20_using_devices    NaN      percent            NaN
# 7444   perc_total_100_20_using_devices    NaN      percent            NaN
# 7462   perc_total_100_20_using_devices    NaN      percent            NaN
# 9916   perc_total_100_20_using_devices    NaN      percent            NaN
# 10349  perc_total_100_20_using_devices    NaN      percent            NaN
# 10363  perc_total_100_20_using_devices    NaN      percent            NaN
# 10485  perc_total_100_20_using_devices    NaN      percent            NaN
# 12052  perc_total_100_20_using_devices    NaN      percent            NaN
# 13544  perc_total_100_20_using_devices    NaN      percent            NaN
# 14860  perc_total_100_20_using_devices    NaN      percent            NaN
# 33818  perc_total_100_20_using_devices    NaN      percent            NaN
# 33819  perc_total_100_20_using_devices    NaN      percent            NaN
# 33820  perc_total_100_20_using_devices    NaN      percent            NaN
# 33821  perc_total_100_20_using_devices    NaN      percent            NaN
# 33822  perc_total_100_20_using_devices    NaN      percent            NaN
# 33823  perc_total_100_20_using_devices    NaN      percent            NaN
# 33824  perc_total_100_20_using_devices    NaN      percent            NaN
# 33825  perc_total_100_20_using_devices    NaN      percent            NaN
# 33826  perc_total_100_20_using_devices    NaN      percent            NaN
# 33827  perc_total_100_20_using_devices    NaN      percent            NaN
# 33828  perc_total_100_20_using_devices    NaN      percent            NaN
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/Wired/Accessibility/Percent Good (total)/data/distribution/ncr_hdcttrbg_2019_2021q3_percent_above_threshold.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                26
# measure              0
# value              200
# measure_type         0
# measure_units    39943
# dtype: int64
#               geoid  region_type  \
# 85     510019902000  block group
# 93     510019901000  block group
# 2568   510539801001  block group
# 6349   511039901000  block group
# 7063   511159901000  block group
# 7181   511199901000  block group
# 7444   511319901000  block group
# 7462   511339901000  block group
# 9916   511838702021  block group
# 10349  511959307003  block group
# 10363  511959312003  block group
# 10485  511999901000  block group
# 12052  516509901000  block group
# 13544  517359901000  block group
# 14860  518000751010  block group
# 33818  240039900000  block group
# 33819  240099901000  block group
# 33820  240178513021  block group
# 33821  240199900000  block group
# 33822  240299900000  block group
# 33823  240359900000  block group
# 33824  240359901000  block group
# 33825  240379900000  block group
# 33826  240399901000  block group
# 33827  240419900000  block group
# 33828  240479900000  block group
#
#                                              region_name  year  \
# 85     Block Group 0, Census Tract 9902, Accomack Cou...   NaN
# 93     Block Group 0, Census Tract 9901, Accomack Cou...   NaN
# 2568   Block Group 1, Census Tract 9801, Dinwiddie Co...   NaN
# 6349   Block Group 0, Census Tract 9901, Lancaster Co...   NaN
# 7063   Block Group 0, Census Tract 9901, Mathews Coun...   NaN
# 7181   Block Group 0, Census Tract 9901, Middlesex Co...   NaN
# 7444   Block Group 0, Census Tract 9901, Northampton ...   NaN
# 7462   Block Group 0, Census Tract 9901, Northumberla...   NaN
# 9916   Block Group 1, Census Tract 8702.02, Sussex Co...   NaN
# 10349  Block Group 3, Census Tract 9307, Wise County,...   NaN
# 10363  Block Group 3, Census Tract 9312, Wise County,...   NaN
# 10485  Block Group 0, Census Tract 9901, York County,...   NaN
# 12052  Block Group 0, Census Tract 9901, Hampton city...   NaN
# 13544  Block Group 0, Census Tract 9901, Poquoson cit...   NaN
# 14860  Block Group 0, Census Tract 751.01, Suffolk ci...   NaN
# 33818  Block Group 0, Census Tract 9900, Anne Arundel...   NaN
# 33819  Block Group 0, Census Tract 9901, Calvert Coun...   NaN
# 33820  Block Group 1, Census Tract 8513.02, Charles C...   NaN
# 33821  Block Group 0, Census Tract 9900, Dorchester C...   NaN
# 33822  Block Group 0, Census Tract 9900, Kent County,...   NaN
# 33823  Block Group 0, Census Tract 9900, Queen Anne's...   NaN
# 33824  Block Group 0, Census Tract 9901, Queen Anne's...   NaN
# 33825  Block Group 0, Census Tract 9900, St. Mary's C...   NaN
# 33826  Block Group 0, Census Tract 9901, Somerset Cou...   NaN
# 33827  Block Group 0, Census Tract 9900, Talbot Count...   NaN
# 33828  Block Group 0, Census Tract 9900, Worcester Co...   NaN
#
#                              measure  value measure_type  measure_units
# 85     perc_total_25_3_using_devices    NaN      percent            NaN
# 93     perc_total_25_3_using_devices    NaN      percent            NaN
# 2568   perc_total_25_3_using_devices    NaN      percent            NaN
# 6349   perc_total_25_3_using_devices    NaN      percent            NaN
# 7063   perc_total_25_3_using_devices    NaN      percent            NaN
# 7181   perc_total_25_3_using_devices    NaN      percent            NaN
# 7444   perc_total_25_3_using_devices    NaN      percent            NaN
# 7462   perc_total_25_3_using_devices    NaN      percent            NaN
# 9916   perc_total_25_3_using_devices    NaN      percent            NaN
# 10349  perc_total_25_3_using_devices    NaN      percent            NaN
# 10363  perc_total_25_3_using_devices    NaN      percent            NaN
# 10485  perc_total_25_3_using_devices    NaN      percent            NaN
# 12052  perc_total_25_3_using_devices    NaN      percent            NaN
# 13544  perc_total_25_3_using_devices    NaN      percent            NaN
# 14860  perc_total_25_3_using_devices    NaN      percent            NaN
# 33818  perc_total_25_3_using_devices    NaN      percent            NaN
# 33819  perc_total_25_3_using_devices    NaN      percent            NaN
# 33820  perc_total_25_3_using_devices    NaN      percent            NaN
# 33821  perc_total_25_3_using_devices    NaN      percent            NaN
# 33822  perc_total_25_3_using_devices    NaN      percent            NaN
# 33823  perc_total_25_3_using_devices    NaN      percent            NaN
# 33824  perc_total_25_3_using_devices    NaN      percent            NaN
# 33825  perc_total_25_3_using_devices    NaN      percent            NaN
# 33826  perc_total_25_3_using_devices    NaN      percent            NaN
# 33827  perc_total_25_3_using_devices    NaN      percent            NaN
# 33828  perc_total_25_3_using_devices    NaN      percent            NaN
# --------------------------------------------------------------------------------
