# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %%
root_dir = '../sdc.broadband_dev'
print(os.path.isdir(root_dir))
# Out:
# True

# %%
paths = [path for path in Path(root_dir).rglob("distribution/**/*.csv.xz")]
print(len(paths))
# Out:
# 37

# %%
tdf = pd.read_csv(paths[0], low_memory=False)

# %%
tdf
# Out:
#                  geoid          region_type region_name  year  \
# 0    51059_sd_braddock  supervisor district    BRADDOCK  2019
# 1    51059_sd_braddock  supervisor district    BRADDOCK  2020
# 2    51059_sd_braddock  supervisor district    BRADDOCK  2021
# 3    51059_sd_braddock  supervisor district    BRADDOCK  2019
# 4    51059_sd_braddock  supervisor district    BRADDOCK  2020
# ..                 ...                  ...         ...   ...
# 211     51059_sd_sully  supervisor district       SULLY  2020
# 212     51059_sd_sully  supervisor district       SULLY  2021
# 213     51059_sd_sully  supervisor district       SULLY  2019
# 214     51059_sd_sully  supervisor district       SULLY  2020
# 215     51059_sd_sully  supervisor district       SULLY  2021
#
#                     measure         value
# 0    avg_down_using_devices    123.092050
# 1    avg_down_using_devices    153.972171
# 2    avg_down_using_devices    213.599194
# 3      avg_down_using_tests    123.568525
# 4      avg_down_using_tests    152.285330
# ..                      ...           ...
# 211                 devices  11131.229417
# 212                 devices   8730.111190
# 213                   tests  30210.251345
# 214                   tests  44014.199937
# 215                   tests  33861.708472
#
# [216 rows x 6 columns]

# %%
def binarize_null(df):
    for col in df.columns:
        df[col] = df[col].apply(lambda x: 1 if pd.isnull(x) else 0)
    return df

# %%
bdf = binarize_null(tdf)

# %%
sns.heatmap(data=bdf, vmin=0, vmax=1).set_title(paths[0].name)
# Out:
# Text(0.5, 1.0, 'va059_spd_sdad_2019_2021_speed_measurements.csv.xz')

# %%
bdf.sum()
# Out:
# geoid          0
# region_type    0
# region_name    0
# year           0
# measure        0
# value          0
# dtype: int64

# %%
tdf.sum()
# Out:
# geoid          0
# region_type    0
# region_name    0
# year           0
# measure        0
# value          0
# dtype: int64

# %%
legacy_val_empty = None
new_val_empty = None

for path in paths:
    df = pd.read_csv(path, low_memory=False)
    print(path)
    bdf = binarize_null(df)
    sns.heatmap(data=bdf, vmin=0, vmax=1).set_title(path.name)
    plt.show()
    print(bdf.sum())
    
    if 'legacy' in str(path):
        if legacy_val_empty is None:
            legacy_val_empty = bdf.sum()
        else:
            legacy_val_empty += bdf.sum()
    else:
        if new_val_empty is None:
            new_val_empty = bdf.sum()
        else:
            new_val_empty += bdf.sum()
    print('-'*80)
# Out:
# ../sdc.broadband_dev/legacy/data/dc.ookla.broadband/distribution/va059_spd_sdad_2019_2021_speed_measurements.csv.xz
# geoid          0
# region_type    0
# region_name    0
# year           0
# measure        0
# value          0
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.ookla.broadband/distribution/va_hdcttr_2019_2021_speed_measurements_fixed.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                 0
# measure              0
# value                0
# measure_type         0
# measure_units    12360
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.ookla.broadband/distribution/ncr_cttrbg_2019_2021_percent_above_threshold_mobile.csv.xz
# geoid                 0
# region_type           0
# region_name           0
# year                 24
# measure               0
# value               492
# measure_type          0
# measure_units    322152
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.ookla.broadband/distribution/va_hdcttr_2019_2021_percent_above_threshold_fixed.csv.xz
# geoid                 0
# region_type           0
# region_name           0
# year                  0
# measure               0
# value                 0
# measure_type          0
# measure_units    146952
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.ookla.broadband/distribution/va_hdcttr_2019_2021_percent_above_threshold_mobile.csv.xz
# geoid                 0
# region_type           0
# region_name           0
# year                  0
# measure               0
# value                 0
# measure_type          0
# measure_units    146928
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.ookla.broadband/distribution/dcmdva_hdcttrbg_2019_2021q3_percent_above_threshold.csv.xz
# geoid                 0
# region_type           0
# region_name           0
# year                624
# measure               0
# value              2712
# measure_type          0
# measure_units    958632
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.ookla.broadband/distribution/dcmdva_hdcttrbg_2019_2021q3_speed_measurements.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                 0
# measure              0
# value                0
# measure_type         0
# measure_units    80016
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.ookla.broadband/distribution/va059_zp_sdad_2019_2021_speed_measurements.csv.xz
# geoid          0
# region_type    0
# region_name    0
# year           0
# measure        0
# value          0
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.ookla.broadband/distribution/va059_pd_sdad_2019_2021_speed_measurements.csv.xz
# geoid          0
# region_type    0
# region_name    0
# year           0
# measure        0
# value          0
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.ookla.broadband/distribution/ncr_cttrbg_2019_2021_speed_measurements_fixed.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                 0
# measure              0
# value                0
# measure_type         0
# measure_units    26892
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.ookla.broadband/distribution/ncr_cttrbg_2019_2021_percent_above_threshold_fixed.csv.xz
# geoid                 0
# region_type           0
# region_name           0
# year                 24
# measure               0
# value               492
# measure_type          0
# measure_units    322224
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.ookla.broadband/distribution/va_hdcttr_2019_2021_speed_measurements_mobile.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                 0
# measure              0
# value                0
# measure_type         0
# measure_units    12382
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.ookla.broadband/distribution/va059_hsr_sdad_2019_2019_speed_measurements.csv.xz
# geoid          0
# region_type    0
# region_name    0
# year           0
# measure        0
# value          0
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.ookla.broadband/distribution/ncr_cttrbg_2019_2021_speed_measurements_mobile.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                 0
# measure              0
# value                0
# measure_type         0
# measure_units    26886
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.acs.broadband/distribution/va_hdcttr_2017_2019_broadband_withoutint_compdev.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                 0
# measure              0
# value              303
# measure_type         0
# measure_units    38358
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.acs.broadband/distribution/dcmdva_hdcttrbg_2017_2019_broadband_withoutint_compdev.csv.xz
# geoid                 0
# region_type           0
# region_name           0
# year                  0
# measure               0
# value              1305
# measure_type          0
# measure_units    242232
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.acs.broadband/distribution/ncr_cttrbg_2017_2019_broadband_withoutint_compdev.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                 0
# measure              0
# value              192
# measure_type         0
# measure_units    80778
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.broadbandnow.broadband.prices/distribution/ncr_cttrbg_broadbandnow_acs_sdad_2021_perc_income_on_internet.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                 0
# measure              0
# value               73
# measure_type         0
# measure_units    35158
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.broadbandnow.broadband.prices/distribution/dmv_tr_broadband_now_2021_internet_package_price.csv.xz
# geoid            0
# region_type      0
# region_name      0
# year             0
# measure          0
# value            0
# measure_type     0
# measure_units    0
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.broadbandnow.broadband.prices/distribution/dcmdva_broadbandnow_acs_sdad_2021_perc_income_on_internet.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                 0
# measure              0
# value              414
# measure_type         0
# measure_units    76504
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.broadbandnow.broadband.prices/distribution/ncr_cttrbg_2021_broadband_now_internet_package_price.csv.xz
# geoid            0
# region_type      0
# region_name      0
# year             0
# measure          0
# value            0
# measure_type     0
# measure_units    0
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.broadbandnow.broadband.prices/distribution/dcmdva_hdcttrbg_2021_broadband_now_internet_package_price.csv.xz
# geoid            0
# region_type      0
# region_name      0
# year             0
# measure          0
# value            0
# measure_type     0
# measure_units    0
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.broadbandnow.broadband.prices/distribution/va_hdcttr_2021_broadband_now_internet_package_price.csv.xz
# geoid            0
# region_type      0
# region_name      0
# year             0
# measure          0
# value            0
# measure_type     0
# measure_units    0
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/legacy/data/dc.broadbandnow.broadband.prices/distribution/dcmdva_hdcttrbg_broadbandnow_acs_sdad_2021_perc_income_on_internet.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                 0
# measure              0
# value              487
# measure_type         0
# measure_units    88865
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/Wired/Affordability/Percentage of income for internet (average)/data/distribution/dcmdva_broadbandnow_acs_sdad_2021_perc_income_on_internet.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                 0
# measure              0
# value              414
# measure_type         0
# measure_units    13358
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/Wired/Affordability/Percentage of income for good internet/data/distribution/dcmdva_broadbandnow_acs_sdad_2021_perc_income_on_internet.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                 0
# measure              0
# value                0
# measure_type         0
# measure_units    12835
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/Wired/Affordability/Percentage of income for fast internet/data/distribution/dcmdva_broadbandnow_acs_sdad_2021_perc_income_on_internet.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                 0
# measure              0
# value                0
# measure_type         0
# measure_units    12492
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/Wired/Adoption/Households with cable, fiber optic, or DSL/data/distribution/dcmdva_hdcttrbg_2017_2019_broadband_withoutint_compdev.csv.xz
# geoid              0
# region_type        0
# region_name        0
# year               0
# measure            0
# value              0
# measure_type       0
# measure_units    579
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/Wired/Adoption/Households with broadband/data/distribution/dcmdva_hdcttrbg_2017_2019_broadband_withoutint_compdev.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                 0
# measure              0
# value              435
# measure_type         0
# measure_units    40179
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/Wired/Adoption/Households without a computer/data/distribution/dcmdva_hdcttrbg_2017_2019_broadband_withoutint_compdev.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                 0
# measure              0
# value              435
# measure_type         0
# measure_units    40179
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/Wired/Adoption/Households without internet access/data/distribution/dcmdva_hdcttrbg_2017_2019_broadband_withoutint_compdev.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                 0
# measure              0
# value              435
# measure_type         0
# measure_units    40179
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/Wired/Accessibility/Percent Fast (internet-connected)/data/distribution/dcmdva_hdcttrbg_2019_2021q3_percent_above_threshold.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                26
# measure              0
# value               26
# measure_type         0
# measure_units    39943
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/Wired/Accessibility/Average Download Speed/data/distribution/dcmdva_hdcttrbg_2019_2021q3_speed_measurements.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                 0
# measure              0
# value                0
# measure_type         0
# measure_units    40008
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/Wired/Accessibility/Percent Good (internet-connected)/data/distribution/dcmdva_hdcttrbg_2019_2021q3_percent_above_threshold.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                26
# measure              0
# value               26
# measure_type         0
# measure_units    39943
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/Wired/Accessibility/Percent Fast (total)/data/distribution/dcmdva_hdcttrbg_2019_2021q3_percent_above_threshold.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                26
# measure              0
# value              200
# measure_type         0
# measure_units    39943
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/Wired/Accessibility/Percent Good (total)/data/distribution/dcmdva_hdcttrbg_2019_2021q3_percent_above_threshold.csv.xz
# geoid                0
# region_type          0
# region_name          0
# year                26
# measure              0
# value              200
# measure_type         0
# measure_units    39943
# dtype: int64
# --------------------------------------------------------------------------------
# ../sdc.broadband_dev/Wired/Accessibility/Average Upload Speed/data/distribution/dcmdva_hdcttrbg_2019_2021q3_speed_measurements.csv.xz
# geoid            0
# region_type      0
# region_name      0
# year             0
# measure          0
# value            0
# measure_type     0
# measure_units    0
# dtype: int64
# --------------------------------------------------------------------------------

# %%
print('legacy val empety: ',legacy_val_empty)
print()
print('new val empty: ',new_val_empty)
# Out:
# legacy val empety:  geoid             0.0
# region_type       0.0
# region_name       0.0
# year            672.0
# measure           0.0
# value          6470.0
# dtype: float64
#
# new val empty:  geoid                 0
# region_type           0
# region_name           0
# year                104
# measure               0
# value              2171
# measure_type          0
# measure_units    359581
# dtype: int64

# %% [markdown]
# # Insepction

# %%
good_df = pd.read_csv('../sdc.broadband_dev/Wired/Accessibility/Percent Good (total)/data/distribution/dcmdva_hdcttrbg_2019_2021q3_percent_above_threshold.csv.xz')
fast_df = pd.read_csv('../sdc.broadband_dev/Wired/Accessibility/Percent Fast (total)/data/distribution/dcmdva_hdcttrbg_2019_2021q3_percent_above_threshold.csv.xz')

# %%
good_df
good_df[good_df['region_type']=='health district']
# Out:
#        geoid      region_type        region_name    year  \
# 21973      1  health district         Alexandria  2019.0
# 21974      1  health district         Alexandria  2021.0
# 21975      1  health district         Alexandria  2020.0
# 21976      2  health district          Alleghany  2021.0
# 21977      2  health district          Alleghany  2020.0
# ...      ...              ...                ...     ...
# 22073     34  health district      West Piedmont  2020.0
# 22074     34  health district      West Piedmont  2019.0
# 22075     35  health district  Western Tidewater  2020.0
# 22076     35  health district  Western Tidewater  2019.0
# 22077     35  health district  Western Tidewater  2021.0
#
#                              measure      value measure_type  measure_units
# 21973  perc_total_25_3_using_devices  79.367134      percent            NaN
# 21974  perc_total_25_3_using_devices  83.898356      percent            NaN
# 21975  perc_total_25_3_using_devices  82.495094      percent            NaN
# 21976  perc_total_25_3_using_devices  76.187560      percent            NaN
# 21977  perc_total_25_3_using_devices  75.506286      percent            NaN
# ...                              ...        ...          ...            ...
# 22073  perc_total_25_3_using_devices  55.683950      percent            NaN
# 22074  perc_total_25_3_using_devices  51.861632      percent            NaN
# 22075  perc_total_25_3_using_devices  74.759785      percent            NaN
# 22076  perc_total_25_3_using_devices  68.185648      percent            NaN
# 22077  perc_total_25_3_using_devices  76.494518      percent            NaN
#
# [105 rows x 8 columns]

# %%
fast_df
# Out:
#               geoid  region_type  \
# 0      510010901001  block group
# 1      510010901002  block group
# 2      510010901003  block group
# 3      510010901004  block group
# 4      510010902001  block group
# ...             ...          ...
# 39938   11001011100        tract
# 39939   11001011100        tract
# 39940         11001       county
# 39941         11001       county
# 39942         11001       county
#
#                                              region_name    year  \
# 0      Block Group 1, Census Tract 901, Accomack Coun...  2019.0
# 1      Block Group 2, Census Tract 901, Accomack Coun...  2019.0
# 2      Block Group 3, Census Tract 901, Accomack Coun...  2019.0
# 3      Block Group 4, Census Tract 901, Accomack Coun...  2019.0
# 4      Block Group 1, Census Tract 902, Accomack Coun...  2019.0
# ...                                                  ...     ...
# 39938  Census Tract 111, District of Columbia, Distri...  2020.0
# 39939  Census Tract 111, District of Columbia, Distri...  2021.0
# 39940         District of Columbia, District of Columbia  2019.0
# 39941         District of Columbia, District of Columbia  2020.0
# 39942         District of Columbia, District of Columbia  2021.0
#
#                                measure      value measure_type  measure_units
# 0      perc_total_100_20_using_devices   0.705755      percent            NaN
# 1      perc_total_100_20_using_devices   0.278100      percent            NaN
# 2      perc_total_100_20_using_devices   0.475628      percent            NaN
# 3      perc_total_100_20_using_devices   0.230163      percent            NaN
# 4      perc_total_100_20_using_devices   0.017623      percent            NaN
# ...                                ...        ...          ...            ...
# 39938  perc_total_100_20_using_devices  70.312214      percent            NaN
# 39939  perc_total_100_20_using_devices  83.572164      percent            NaN
# 39940  perc_total_100_20_using_devices  59.655642      percent            NaN
# 39941  perc_total_100_20_using_devices  71.911771      percent            NaN
# 39942  perc_total_100_20_using_devices  75.913337      percent            NaN
#
# [39943 rows x 8 columns]

# %%
test_df = pd.read_csv('../sdc.broadband_dev/legacy/data/dc.broadbandnow.broadband.prices/distribution/dcmdva_hdcttrbg_broadbandnow_acs_sdad_2021_perc_income_on_internet.csv.xz')

# %%
test_df[test_df['value'].isnull()]
# Out:
#               geoid  region_type  \
# 263     51059980300        tract
# 380     51153980100        tract
# 543     51059980100        tract
# 565     51107980100        tract
# 577     51013980100        tract
# ...             ...          ...
# 62893  240419900000  block group
# 62894  240359901000  block group
# 62895  240099901000  block group
# 62896  240479900000  block group
# 62897  240299900000  block group
#
#                                              region_name  year  \
# 263          Census Tract 9803, Fairfax County, Virginia  2021
# 380    Census Tract 9801, Prince William County, Virg...  2021
# 543          Census Tract 9801, Fairfax County, Virginia  2021
# 565          Census Tract 9801, Loudoun County, Virginia  2021
# 577        Census Tract 9801, Arlington County, Virginia  2021
# ...                                                  ...   ...
# 62893  Block Group 0, Census Tract 9900, Talbot Count...  2021
# 62894  Block Group 0, Census Tract 9901, Queen Anne's...  2021
# 62895  Block Group 0, Census Tract 9901, Calvert Coun...  2021
# 62896  Block Group 0, Census Tract 9900, Worcester Co...  2021
# 62897  Block Group 0, Census Tract 9900, Kent County,...  2021
#
#                            measure  value measure_type  measure_units
# 263    perc_income_avg_nat_package    NaN      percent            NaN
# 380    perc_income_avg_nat_package    NaN      percent            NaN
# 543    perc_income_avg_nat_package    NaN      percent            NaN
# 565    perc_income_avg_nat_package    NaN      percent            NaN
# 577    perc_income_avg_nat_package    NaN      percent            NaN
# ...                            ...    ...          ...            ...
# 62893  perc_income_avg_nat_package    NaN      percent            NaN
# 62894  perc_income_avg_nat_package    NaN      percent            NaN
# 62895  perc_income_avg_nat_package    NaN      percent            NaN
# 62896  perc_income_avg_nat_package    NaN      percent            NaN
# 62897  perc_income_avg_nat_package    NaN      percent            NaN
#
# [487 rows x 8 columns]
